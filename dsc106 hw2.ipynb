# %%
import pandas as pd
import numpy as np
import os

# %%
data_d=os.path.join('daily_sales.csv') 
data_m=os.path.join('monthly_sales.csv')

# %%
day=pd.read_csv(data_1)

# %%
month=pd.read_csv(data_m)

# %%
month['year']=month['Month, Year'].apply(lambda x: x[-2:]).astype(int)

# %%
year_sum=month.drop(['Month, Year'],axis=1).groupby('year').sum()

# %%
year_sum
# Out:
#          HM-NE    CF-NE    FF-NE     HM-SW    CF-SW    FF-SW     HM-NW  \
# year
# 16    15018452  6342284  3782250  15089397  6184218  3723534  14674588
# 17    17741690  7367446  4390884  17420447  7232191  4382457  17131715
# 18    19004783  7956944  4803865  18756738  7821310  4664654  18508629
# 19    13597409  5566546  3368943  13155125  5578234  3333492  13257068
#
#         CF-NW    FF-NW     HM-SE    CF-SE    FF-SE      HM-C     CF-C     FF-C
# year
# 16    6091022  3655429  14504772  6063851  3614955  14255683  5921843  3623867
# 17    7162448  4282933  16864459  7027026  4217404  16612812  6922107  4221290
# 18    7708299  4639853  18178265  7575247  4544941  17965178  7542971  4522787
# 19    5379660  3242963  12781118  5373326  3237239  12748702  5337645  3173024

# %%
year_sum
# Out:
#          HM-NE    CF-NE    FF-NE     HM-SW    CF-SW    FF-SW     HM-NW  \
# year
# 16    15018452  6342284  3782250  15089397  6184218  3723534  14674588
# 17    17741690  7367446  4390884  17420447  7232191  4382457  17131715
# 18    19004783  7956944  4803865  18756738  7821310  4664654  18508629
# 19    13597409  5566546  3368943  13155125  5578234  3333492  13257068
#
#         CF-NW    FF-NW     HM-SE    CF-SE    FF-SE      HM-C     CF-C     FF-C
# year
# 16    6091022  3655429  14504772  6063851  3614955  14255683  5921843  3623867
# 17    7162448  4282933  16864459  7027026  4217404  16612812  6922107  4221290
# 18    7708299  4639853  18178265  7575247  4544941  17965178  7542971  4522787
# 19    5379660  3242963  12781118  5373326  3237239  12748702  5337645  3173024

# %%
year_sub=year_sum.rename(columns=lambda x: x[-2:])

# %%
year_sub.iloc[:,0:3].sum(axis=1)
# Out:
# year
# 16    25142986
# 17    29500020
# 18    31765592
# 19    22532898
# dtype: int64

# %%
for i in range(0,15,3):
    five_place[i]=year_sub.iloc[:,i:i+3].sum(axis=1).to_frame()[0]

# %%
five_place=pd.DataFrame()

# %%
year_sub.iloc[:,0:0+3].sum(axis=1).to_frame()
# Out:
#              0
# year
# 16    25142986
# 17    29500020
# 18    31765592
# 19    22532898

# %%
five_place.columns=['NE','SW','NW','SE','C']

# %%
five_place
# Out:
#             NE        SW        NW        SE         C
# year
# 16    25142986  24997149  24421039  24183578  23801393
# 17    29500020  29035095  28577096  28108889  27756209
# 18    31765592  31242702  30856781  30298453  30030936
# 19    22532898  22066851  21879691  21391683  21259371

# %%
day_sum=day[:-3].groupby('Unnamed: 0').sum()

# %%
# Out:
#    Unnamed: 0        Day  HM-NE  CF-NE  FF-NE  HM-SW  CF-SW  FF-SW  HM-NW  \
# 0      Friday   1/1/2016  37240  16077   8446  39249  16565  10204  37271
# 1    Saturday   1/2/2016  36258  14726   7950  38106  14003   7316  35021
# 2      Sunday   1/3/2016  37007  15103   8397  35494  15987   8683  35369
# 3      Monday   1/4/2016  37590  16413   9537  33666  15114   8429  37993
# 4     Tuesday   1/5/2016  38036  16199  10123  33528  13721  10085  37854
# 5   Wednesday   1/6/2016  38187  16386   8410  33608  14322   9652  36343
# 6    Thursday   1/7/2016  38095  16045  11791  33007  15068   8985  35901
# 7      Friday   1/8/2016  34685  15058   8179  38964  13608  10985  36279
# 8    Saturday   1/9/2016  35059  14585   7193  33637  14035   7616  38059
# 9      Sunday  1/10/2016  36906  16905  10580  39361  14788   7105  35332
# 10     Monday  1/11/2016  36893  16771  10091  35750  16565   9506  37802
# 11    Tuesday  1/12/2016  37243  15642   9247  35040  16132   8424  36105
# ...

# %%
five_place_d=pd.DataFrame()
for i in range(0,15,3):
    five_place_d[i]=day_sum.iloc[:,i:i+3].sum(axis=1).to_frame()[0]
five_place_d.columns=['NE','SW','NW','SE','C']

# %%
hm_list=[]
for i in range(0,15,3):
    hm_list.append(i)
hm_list
cf_list=np.array(hm_list)+1
ff_list=cf_list+1

# %%
hm_m=day_sum.iloc[:,hm_list].sum(axis=1).to_frame()
cf_m=day_sum.iloc[:,cf_list].sum(axis=1).to_frame()
ff_m=day_sum.iloc[:,ff_list].sum(axis=1).to_frame()

# %%
three_d=pd.concat([hm_m,cf_m,ff_m],axis=1)

# %%
hm_y=year_sum.iloc[:,hm_list].sum(axis=1).to_frame()
cf_y=year_sum.iloc[:,cf_list].sum(axis=1).to_frame()
ff_y=year_sum.iloc[:,ff_list].sum(axis=1).to_frame()

# %%
three_m=pd.concat([hm_y,cf_y,ff_y],axis=1)

# %%
three_d.columns=['HM','CF','FF']
three_m.columns=['HM','CF','FF']

# %%
three_d.sort_index()
# Out:
#                 HM      CF      FF
# Unnamed: 0
# Friday      731789  304994  210357
# Monday      725474  308175  179006
# Saturday    721762  294393  161418
# Sunday      720019  306826  158830
# Thursday    717869  303620  193430
# Tuesday     721367  302101  176625
# Wednesday   725219  305797  184822

# %%
day_sum.to_csv('total_sales_7days.csv')

# %%
year_sum.to_csv('total_sales_4years.csv')

# %%
five_place.to_csv('total_sales_4yearsbyplace.csv')

# %%
three_m.to_csv('total_sales_4years_bytype.csv')
three_d.to_csv('total_sales_7days_bytype.csv')

# %%
month['sum']=month.drop(columns=['year']).sum(axis=1)

# %%
month[0:12].to_csv('yaer_sales_16.csv')
month[12:24].to_csv('yaer_sales_17.csv')
month[24:36].to_csv('yaer_sales_18.csv')
month[36:].to_csv('yaer_sales_19.csv')

# %%
# Out:
#    Month, Year    HM-NE   CF-NE   FF-NE    HM-SW   CF-SW   FF-SW    HM-NW  \
# 0       Jan-16  1140955  494802  285238  1124565  468568  281141  1111618
# 1       Feb-16  1175529  489804  293882  1200559  480616  288369  1188037
# 2       Mar-16  1235995  494802  296881  1220454  508522  293148  1151657
# 3       Apr-16  1186592  514593  296648  1213616  485843  291505  1149180
# 4       May-16  1272450  530187  305637  1249686  520702  312421  1187579
# 5       Jun-16  1235025  535597  321358  1213908  505795  303477  1239785
# 6       Jul-16  1284426  535177  321106  1269486  508209  317371  1202069
# 7       Aug-16  1323348  551395  330837  1358134  565889  326218  1283993
# 8       Sep-16  1284426  535177  334213  1268860  528691  330162  1295077
# 9       Oct-16  1280303  555233  333140  1315120  526477  328780  1301675
# 10      Nov-16  1319100  572058  343235  1348519  561883  337129  1276693
# 11      Dec-16  1280303  533459  320075  1306490  523023  313813  1287225
# ...

# %%
month['hm_total']=month.iloc[:,np.array(hm_list)+1].sum(axis=1)

# %%
month
# Out:
#    Month, Year    HM-NE   CF-NE   FF-NE    HM-SW   CF-SW   FF-SW    HM-NW  \
# 0       Jan-16  1140955  494802  285238  1124565  468568  281141  1111618
# 1       Feb-16  1175529  489804  293882  1200559  480616  288369  1188037
# 2       Mar-16  1235995  494802  296881  1220454  508522  293148  1151657
# 3       Apr-16  1186592  514593  296648  1213616  485843  291505  1149180
# 4       May-16  1272450  530187  305637  1249686  520702  312421  1187579
# 5       Jun-16  1235025  535597  321358  1213908  505795  303477  1239785
# 6       Jul-16  1284426  535177  321106  1269486  508209  317371  1202069
# 7       Aug-16  1323348  551395  330837  1358134  565889  326218  1283993
# 8       Sep-16  1284426  535177  334213  1268860  528691  330162  1295077
# 9       Oct-16  1280303  555233  333140  1315120  526477  328780  1301675
# 10      Nov-16  1319100  572058  343235  1348519  561883  337129  1276693
# 11      Dec-16  1280303  533459  320075  1306490  523023  313813  1287225
# ...

# %%
# Out:
#    Month, Year    HM-NE   CF-NE   FF-NE    HM-SW   CF-SW   FF-SW    HM-NW  \
# 0       Jan-16  1140955  494802  285238  1124565  468568  281141  1111618
# 1       Feb-16  1175529  489804  293882  1200559  480616  288369  1188037
# 2       Mar-16  1235995  494802  296881  1220454  508522  293148  1151657
# 3       Apr-16  1186592  514593  296648  1213616  485843  291505  1149180
# 4       May-16  1272450  530187  305637  1249686  520702  312421  1187579
# 5       Jun-16  1235025  535597  321358  1213908  505795  303477  1239785
# 6       Jul-16  1284426  535177  321106  1269486  508209  317371  1202069
# 7       Aug-16  1323348  551395  330837  1358134  565889  326218  1283993
# 8       Sep-16  1284426  535177  334213  1268860  528691  330162  1295077
# 9       Oct-16  1280303  555233  333140  1315120  526477  328780  1301675
# 10      Nov-16  1319100  572058  343235  1348519  561883  337129  1276693
# 11      Dec-16  1280303  533459  320075  1306490  523023  313813  1287225
# ...

# %%
year_sum.sum(axis=1)
# Out:
# year
# 16    122546145
# 17    142977309
# 18    154194464
# 19    109130494
# dtype: int64

# %%
day_sum
# Out:
#              HM-NE  CF-NE  FF-NE   HM-SW  CF-SW  FF-SW   HM-NW  CF-NW  FF-NW  \
# Unnamed: 0
# Friday      182391  78508  38171  189142  78918  54105  180608  77114  52028
# Monday      147407  65644  37137  139664  64460  36965  149051  61370  34599
# Saturday    181806  74971  37001  179746  70875  39964  176661  75882  42683
# Sunday      187583  79915  49378  183703  76540  38964  173437  79001  39033
# Thursday    146544  65878  47190  143854  57932  37563  141652  65002  37095
# Tuesday     148537  64111  38306  142676  59035  35566  144634  61986  35151
# Wednesday   146687  65775  38055  145780  60808  38014  145575  61724  37315
#
#              HM-SE  CF-SE  FF-SE    HM-C   CF-C   FF-C
# Unnamed: 0
# Friday      177534  73476  58847  179930  71480  60683
# Monday      140641  57166  34851  148711  59535  35454
# Saturday    180867  73679  39157  182752  73896  41727
# Sunday      173440  74059  36614  179119  74664  37422
# ...

# %%
day
# Out:
#    Unnamed: 0        Day  HM-NE  CF-NE  FF-NE  HM-SW  CF-SW  FF-SW  HM-NW  \
# 0      Friday   1/1/2016  37240  16077   8446  39249  16565  10204  37271
# 1    Saturday   1/2/2016  36258  14726   7950  38106  14003   7316  35021
# 2      Sunday   1/3/2016  37007  15103   8397  35494  15987   8683  35369
# 3      Monday   1/4/2016  37590  16413   9537  33666  15114   8429  37993
# 4     Tuesday   1/5/2016  38036  16199  10123  33528  13721  10085  37854
# 5   Wednesday   1/6/2016  38187  16386   8410  33608  14322   9652  36343
# 6    Thursday   1/7/2016  38095  16045  11791  33007  15068   8985  35901
# 7      Friday   1/8/2016  34685  15058   8179  38964  13608  10985  36279
# 8    Saturday   1/9/2016  35059  14585   7193  33637  14035   7616  38059
# 9      Sunday  1/10/2016  36906  16905  10580  39361  14788   7105  35332
# 10     Monday  1/11/2016  36893  16771  10091  35750  16565   9506  37802
# 11    Tuesday  1/12/2016  37243  15642   9247  35040  16132   8424  36105
# ...
